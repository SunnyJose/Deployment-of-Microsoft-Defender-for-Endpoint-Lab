# %% [markdown]
# <a href="https://colab.research.google.com/github/SunnyJose/Deployment-of-Microsoft-Defender-for-Endpoint-Lab/blob/main/Fraud_Detection_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# !pip install Matplotlib

# %%
# !pip install seaborn

# %%
# !pip install scikit-learn

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Verify the installation by printing the versions
print(pd.__version__)
print(sns.__version__)
# Out:
# 2.2.2
# 0.13.2

# %% [markdown]
# # New Section
